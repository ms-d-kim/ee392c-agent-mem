# %% [markdown]
# # Trace analysis — first plots
#
# Lightning-pitch plots:
# 1. Lifetime CDF per memory class
# 2. Footprint over time (stacked area)
# 3. Duplication factor over time / vs. step count

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from analysis.load_traces import load_trace, load_system_trace
from analysis.lifetime import compute_logical_presence_lifetime
from analysis.duplication import compute_duplication_over_time

# %%
# Load synthetic first to validate tracer correctness
df = load_trace(Path('../traces/synthetic.jsonl'))
df.head()

# %%
# TODO: real-task traces
# df_real = load_trace(Path('../traces/swe_task_001.jsonl'))
